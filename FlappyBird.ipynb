# %%
# !pip install flappy-bird-gymnasium
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.9.1 Requires-Python >=3.6.0,<3.11; 0.9.2 Requires-Python >=3.8.0,<3.11
# ERROR: Could not find a version that satisfies the requirement stable-retro (from versions: none)
# ERROR: No matching distribution found for stable-retro
# Requirement already satisfied: stable_baselines3[extra] in c:\users\josh\anaconda3\lib\site-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (1.24.3)
# Requirement already satisfied: torch>=1.13 in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (2.2.2)
# Requirement already satisfied: cloudpickle in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (3.7.2)
# Requirement already satisfied: opencv-python in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (4.9.0.80)
# Requirement already satisfied: pygame in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (2.16.2)
# Requirement already satisfied: psutil in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (4.65.0)
# Requirement already satisfied: rich in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (13.7.1)
# Collecting shimmy[atari]~=1.3.0 (from stable_baselines3[extra])
#   Obtaining dependency information for shimmy[atari]~=1.3.0 from https://files.pythonhosted.org/packages/dc/f9/07ef16463db14ac1b30f149c379760f5cacf3fc677b295d29a92f3127914/Shimmy-1.3.0-py3-none-any.whl.metadata
#   Using cached Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in c:\users\josh\anaconda3\lib\site-packages (from stable_baselines3[extra]) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable_baselines3[extra])
#   Obtaining dependency information for autorom[accept-rom-license]~=0.6.1 from https://files.pythonhosted.org/packages/02/e1/90b168a5dbc89a4e9b2206a99238f3ea3fc281052bb2dc236d4aa15e5e87/AutoROM-0.6.1-py3-none-any.whl.metadata
#   Using cached AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in c:\users\josh\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\users\josh\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\josh\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\josh\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3[extra]) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\josh\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3[extra]) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\josh\anaconda3\lib\site-packages (from shimmy[atari]~=1.3.0->stable_baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.62.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (3.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\josh\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (2.2.3)
# Requirement already satisfied: filelock in c:\users\josh\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (3.9.0)
# Requirement already satisfied: sympy in c:\users\josh\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in c:\users\josh\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\josh\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\josh\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (2023.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\josh\anaconda3\lib\site-packages (from matplotlib->stable_baselines3[extra]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\josh\anaconda3\lib\site-packages (from matplotlib->stable_baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\josh\anaconda3\lib\site-packages (from matplotlib->stable_baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\josh\anaconda3\lib\site-packages (from matplotlib->stable_baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\josh\anaconda3\lib\site-packages (from matplotlib->stable_baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\josh\anaconda3\lib\site-packages (from matplotlib->stable_baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\josh\anaconda3\lib\site-packages (from matplotlib->stable_baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josh\anaconda3\lib\site-packages (from pandas->stable_baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\josh\anaconda3\lib\site-packages (from pandas->stable_baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\josh\anaconda3\lib\site-packages (from rich->stable_baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\josh\anaconda3\lib\site-packages (from rich->stable_baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\josh\anaconda3\lib\site-packages (from tqdm->stable_baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\users\josh\anaconda3\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable_baselines3[extra]) (6.4.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\josh\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable_baselines3[extra]) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\josh\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable_baselines3[extra]) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\josh\anaconda3\lib\site-packages (from sympy->torch>=1.13->stable_baselines3[extra]) (1.3.0)
# Using cached AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Using cached Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Installing collected packages: shimmy, autorom
#   Attempting uninstall: shimmy
#     Found existing installation: Shimmy 0.2.1
#     Uninstalling Shimmy-0.2.1:
#       Successfully uninstalled Shimmy-0.2.1
#   Attempting uninstall: autorom
#     Found existing installation: AutoROM 0.4.2
#     Uninstalling AutoROM-0.4.2:
#       Successfully uninstalled AutoROM-0.4.2
# Successfully installed autorom-0.6.1 shimmy-1.3.0

# %%
import flappy_bird_gymnasium
import gymnasium
from stable_baselines3 import PPO

# %%
env = gymnasium.make("FlappyBird-v0", use_lidar=True)

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=200000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 315      |
# |    ep_rew_mean     | 27       |
# | time/              |          |
# |    fps             | 181      |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 660          |
# |    ep_rew_mean          | 57.6         |
# | time/                   |              |
# |    fps                  | 152          |
# |    iterations           | 2            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0016406217 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0401      |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.746        |
# |    n_updates            | 1510         |
# |    policy_gradient_loss | -1.73e-05    |
# |    value_loss           | 1.39         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 161        |
# |    ep_rew_mean          | 10.4       |
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 3          |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02104338 |
# |    clip_fraction        | 0.0478     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.055     |
# |    explained_variance   | 0.41       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.301      |
# |    n_updates            | 1520       |
# |    policy_gradient_loss | -0.00157   |
# |    value_loss           | 0.627      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 9.82        |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 4           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.043399513 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.125      |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6         |
# |    n_updates            | 1530        |
# |    policy_gradient_loss | 0.00841     |
# |    value_loss           | 3.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 5           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015843082 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0677     |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 1540        |
# |    policy_gradient_loss | 0.00677     |
# |    value_loss           | 2.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 6           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007314289 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0441     |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.964       |
# |    n_updates            | 1550        |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 1.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | 9.75        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 7           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023900729 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0398     |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.42        |
# |    n_updates            | 1560        |
# |    policy_gradient_loss | 0.00214     |
# |    value_loss           | 0.889       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | 4.19        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 8           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008604506 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.743       |
# |    n_updates            | 1570        |
# |    policy_gradient_loss | 0.00444     |
# |    value_loss           | 1.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 5.41        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 9           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007163875 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.28       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.826       |
# |    n_updates            | 1580        |
# |    policy_gradient_loss | -0.000493   |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 6.02        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 10          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007412396 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0851     |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.693       |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 1.99        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 7.88         |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 11           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0084775565 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0473      |
# |    explained_variance   | 0.522        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.846        |
# |    n_updates            | 1600         |
# |    policy_gradient_loss | -0.00493     |
# |    value_loss           | 1.34         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 12          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008333716 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0467     |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.494       |
# |    n_updates            | 1610        |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 13          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010986954 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0353     |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.546       |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | -0.000808   |
# |    value_loss           | 1.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 13.9        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 14          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010303157 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0439     |
# |    explained_variance   | 0.00289     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0506      |
# |    n_updates            | 1630        |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 0.354       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 15          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009479411 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0454     |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 1640        |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 0.724       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 240          |
# |    ep_rew_mean          | 15           |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 16           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0066318465 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0418      |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.265        |
# |    n_updates            | 1650         |
# |    policy_gradient_loss | 7.43e-05     |
# |    value_loss           | 0.792        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 17           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0058639813 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0306      |
# |    explained_variance   | 0.37         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.114        |
# |    n_updates            | 1660         |
# |    policy_gradient_loss | 0.000661     |
# |    value_loss           | 0.313        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | 19.1         |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 18           |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0048335725 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0468      |
# |    explained_variance   | 0.463        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.507        |
# |    n_updates            | 1670         |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 1.19         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | 21.5        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 19          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006067834 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0386     |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.149       |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | 0.00062     |
# |    value_loss           | 0.556       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | 21.5        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 20          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005296599 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0285     |
# |    explained_variance   | 0.0971      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.00123    |
# |    value_loss           | 0.905       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 354         |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 21          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015090941 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0259     |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.161       |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | 0.00162     |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 26.5        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 22          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007115336 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0404     |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.611       |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 1.77        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 376          |
# |    ep_rew_mean          | 27.3         |
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 23           |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0037112816 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0302      |
# |    explained_variance   | -0.152       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 1720         |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.98         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 406          |
# |    ep_rew_mean          | 30           |
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 24           |
# |    time_elapsed         | 381          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0071251392 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0267      |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.339        |
# |    n_updates            | 1730         |
# |    policy_gradient_loss | -0.000566    |
# |    value_loss           | 0.5          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | 30.2        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 25          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.025049858 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0389     |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 0.565       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | 29.9         |
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 26           |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0045680897 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0719      |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.222        |
# |    n_updates            | 1750         |
# |    policy_gradient_loss | -0.000827    |
# |    value_loss           | 1.33         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | 31.8        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 27          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009796154 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.064      |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.719       |
# |    n_updates            | 1760        |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 1.1         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | 33.4         |
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 28           |
# |    time_elapsed         | 441          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0044829743 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.123       |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29         |
# |    n_updates            | 1770         |
# |    policy_gradient_loss | 0.000849     |
# |    value_loss           | 3.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 33.2        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 29          |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007467119 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.105      |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 3.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 404         |
# |    ep_rew_mean          | 32.9        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 30          |
# |    time_elapsed         | 471         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013061223 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0464     |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.787       |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.0078     |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 392         |
# |    ep_rew_mean          | 32.3        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 31          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009257492 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0335     |
# |    explained_variance   | -0.0754     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.266       |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 0.906       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 353         |
# |    ep_rew_mean          | 28.7        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 32          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008368909 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.048      |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.337       |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 0.657       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | 26           |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 33           |
# |    time_elapsed         | 518          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0127223525 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0481      |
# |    explained_variance   | 0.401        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.949        |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 1.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 21.8         |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 34           |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0048330715 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0477      |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.901        |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 0.847        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 35          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007999734 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.481       |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.00536     |
# |    value_loss           | 1.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 36          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008681912 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.13       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.851       |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 2.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 16.3        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 37          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008041542 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0808     |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.757       |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 1.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 38          |
# |    time_elapsed         | 597         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009395816 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0449     |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.222       |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 1.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 39          |
# |    time_elapsed         | 612         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012704659 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0305     |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 0.508       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 21.1        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 40          |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013715191 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0363     |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.256       |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 1.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 41          |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009465643 |
# |    clip_fraction        | 0.0226      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0245     |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.000687   |
# |    value_loss           | 0.622       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 312         |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 42          |
# |    time_elapsed         | 658         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006402481 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0319     |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.462       |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.0015      |
# |    value_loss           | 1.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | 25.8        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 43          |
# |    time_elapsed         | 673         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005663926 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0391     |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.386       |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 0.903       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 349          |
# |    ep_rew_mean          | 27.4         |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 44           |
# |    time_elapsed         | 688          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0040186816 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.029       |
# |    explained_variance   | 0.365        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.171        |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 0.705        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 366          |
# |    ep_rew_mean          | 29.1         |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 45           |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0033737426 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0294      |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.313        |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.924        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 366          |
# |    ep_rew_mean          | 29.1         |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 46           |
# |    time_elapsed         | 719          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0074326135 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0316      |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05         |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 1.38         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | 32.9        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 47          |
# |    time_elapsed         | 735         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014789833 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0221     |
# |    explained_variance   | -0.0995     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0432      |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | -0.000439   |
# |    value_loss           | 0.224       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 420         |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 48          |
# |    time_elapsed         | 750         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004828195 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.036      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.777       |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 371         |
# |    ep_rew_mean          | 27.3        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 49          |
# |    time_elapsed         | 768         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005562123 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0486     |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 0.585       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | 21.5        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 50          |
# |    time_elapsed         | 787         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.016712457 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.435      |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.397       |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | 0.00302     |
# |    value_loss           | 1.63        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | 15.6         |
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 51           |
# |    time_elapsed         | 807          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0038477052 |
# |    clip_fraction        | 0.0646       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.16         |
# |    n_updates            | 2000         |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 3.55         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 52          |
# |    time_elapsed         | 824         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011375399 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.208      |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36        |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 3.39        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 237          |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 53           |
# |    time_elapsed         | 840          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0050134985 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0635      |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.77         |
# |    n_updates            | 2020         |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 1.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 247          |
# |    ep_rew_mean          | 15           |
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 54           |
# |    time_elapsed         | 856          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0029384124 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0256      |
# |    explained_variance   | 0.0237       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.24         |
# |    n_updates            | 2030         |
# |    policy_gradient_loss | -0.00066     |
# |    value_loss           | 0.616        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 233          |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 55           |
# |    time_elapsed         | 871          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0068471297 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# ...
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 1.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 4.58        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 81          |
# |    time_elapsed         | 1300        |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.005945948 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0536     |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.177       |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00044    |
# |    value_loss           | 0.874       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | 5.26        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 82          |
# |    time_elapsed         | 1318        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.004761476 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0638     |
# |    explained_variance   | 0.0973      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.435       |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00126    |
# |    value_loss           | 1.22        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | 7.21       |
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 83         |
# |    time_elapsed         | 1337       |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.04893232 |
# |    clip_fraction        | 0.0522     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0715    |
# |    explained_variance   | 0.0305     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.788      |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | -0.0036    |
# |    value_loss           | 1.04       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 8.26        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 84          |
# |    time_elapsed         | 1360        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.015041623 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 9.88        |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 85          |
# |    time_elapsed         | 1382        |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.012640236 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0957     |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.508       |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 1.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 9.88        |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 86          |
# |    time_elapsed         | 1405        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.008367328 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.102      |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.559       |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 1.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 87          |
# |    time_elapsed         | 1426        |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.012689281 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0334     |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.204       |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00414    |
# |    value_loss           | 0.645       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 88          |
# |    time_elapsed         | 1445        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.012348588 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0515     |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.489       |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.0013     |
# |    value_loss           | 1.02        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 279          |
# |    ep_rew_mean          | 16           |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 89           |
# |    time_elapsed         | 1466         |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0058045397 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0852      |
# |    explained_variance   | 0.41         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.664        |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 1.58         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 299        |
# |    ep_rew_mean          | 18         |
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 90         |
# |    time_elapsed         | 1481       |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.00983227 |
# |    clip_fraction        | 0.0313     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0387    |
# |    explained_variance   | 0.294      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.535      |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | -0.000824  |
# |    value_loss           | 0.657      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 91          |
# |    time_elapsed         | 1498        |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.006790839 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0465     |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.431       |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | 0.000421    |
# |    value_loss           | 0.709       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 20          |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 92          |
# |    time_elapsed         | 1513        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.004878956 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0533     |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.803       |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.000583   |
# |    value_loss           | 1.2         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 326        |
# |    ep_rew_mean          | 20.3       |
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 93         |
# |    time_elapsed         | 1528       |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.01223755 |
# |    clip_fraction        | 0.0755     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.152     |
# |    explained_variance   | 0.632      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.08       |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.00017   |
# |    value_loss           | 2.23       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 94          |
# |    time_elapsed         | 1544        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.006692578 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.629       |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 1.84        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 22           |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 95           |
# |    time_elapsed         | 1560         |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0054396223 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0398      |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.353        |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.788        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 23.7        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 96          |
# |    time_elapsed         | 1580        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004540699 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0639     |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.408       |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 97          |
# |    time_elapsed         | 1596        |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.009390537 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.056      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.578       |
# |    n_updates            | 2460        |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 402         |
# |    ep_rew_mean          | 26.6        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 98          |
# |    time_elapsed         | 1612        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.054855578 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0352     |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 2470        |
# |    policy_gradient_loss | -0.000676   |
# |    value_loss           | 0.458       |
# -----------------------------------------

# %%
env = gymnasium.make("FlappyBird-v0", render_mode="human", use_lidar=True)

# %%
obs, _ = env.reset()
while True:
    # Next action:
    # (feed the observation to your agent here)
    action, _ = model.predict(obs, deterministic=True)

    # Processing:
    obs, reward, terminated, _, info = env.step(action)
    
    # Checking if the player is still alive
    if terminated:
        break

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[139], line 8
#       5 action, _ = model.predict(obs, deterministic=True)
#       7 # Processing:
# ----> 8 obs, reward, terminated, _, info = env.step(action)
#      10 # Checking if the player is still alive
#      11 if terminated:
#
# File ~\anaconda3\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~\anaconda3\Lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~\anaconda3\Lib\site-packages\flappy_bird_gymnasium\envs\flappy_bird_env.py:260, in FlappyBirdEnv.step(self, action)
#     257         low_pipe["y"] = new_low_pipe["y"]
#     259 if self.render_mode == "human":
# --> 260     self.render()
#     262 obs, reward_private_zone = self._get_observation()
#     263 if reward is None:
#
# File ~\anaconda3\Lib\site-packages\flappy_bird_gymnasium\envs\flappy_bird_env.py:407, in FlappyBirdEnv.render(self)
#     404     self._make_display()
#     406 self._update_display()
# --> 407 self._fps_clock.tick(self.metadata["render_fps"])
#
# KeyboardInterrupt:
