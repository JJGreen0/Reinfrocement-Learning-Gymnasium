# %%
# !pip install "gymnasium[atari, accept-rom-license]"
# Out:
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023C4E52E050>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/83/aa/e2695fa0c93b39cfe2065fcd189e7eb2db88f6e0922e932fc615827070da/AutoROM-0.4.2-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023C4E52E750>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/83/aa/e2695fa0c93b39cfe2065fcd189e7eb2db88f6e0922e932fc615827070da/AutoROM-0.4.2-py3-none-any.whl.metadata
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in c:\users\josh\anaconda3\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\josh\anaconda3\lib\site-packages (from gymnasium[accept-rom-license,atari]) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\josh\anaconda3\lib\site-packages (from gymnasium[accept-rom-license,atari]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\josh\anaconda3\lib\site-packages (from gymnasium[accept-rom-license,atari]) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\josh\anaconda3\lib\site-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gymnasium[accept-rom-license,atari])
#   Obtaining dependency information for autorom[accept-rom-license]~=0.4.2 from https://files.pythonhosted.org/packages/83/aa/e2695fa0c93b39cfe2065fcd189e7eb2db88f6e0922e932fc615827070da/AutoROM-0.4.2-py3-none-any.whl.metadata
#   Downloading AutoROM-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting shimmy[atari]<1.0,>=0.1.0 (from gymnasium[accept-rom-license,atari])
#   Obtaining dependency information for shimmy[atari]<1.0,>=0.1.0 from https://files.pythonhosted.org/packages/6f/d3/3d3787570f0cb16ba37a4fbd604498d8ee04ce987b7c8564a13d2c1858cf/Shimmy-0.2.1-py3-none-any.whl.metadata
#   Downloading Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: click in c:\users\josh\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (8.0.4)
# Requirement already satisfied: requests in c:\users\josh\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\josh\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (4.65.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\josh\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (0.6.1)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\josh\anaconda3\lib\site-packages (from shimmy[atari]<1.0,>=0.1.0->gymnasium[accept-rom-license,atari]) (0.8.1)
# Requirement already satisfied: importlib-resources in c:\users\josh\anaconda3\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0->gymnasium[accept-rom-license,atari]) (6.4.0)
# Requirement already satisfied: colorama in c:\users\josh\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josh\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license,atari]) (2023.7.22)
# Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Using cached Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Installing collected packages: shimmy, autorom
#   Attempting uninstall: shimmy
#     Found existing installation: Shimmy 1.3.0
#     Uninstalling Shimmy-1.3.0:
#       Successfully uninstalled Shimmy-1.3.0
#   Attempting uninstall: autorom
#     Found existing installation: AutoROM 0.6.1
#     Uninstalling AutoROM-0.6.1:
#       Successfully uninstalled AutoROM-0.6.1
# Successfully installed autorom-0.4.2 shimmy-0.2.1

# %%
import gymnasium as gym
from gymnasium.utils.play import play
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os
env = gym.make('ALE/Alien-v5', render_mode='rgb_array')
play(env, zoom=3)
# Out:
# C:\Users\josh\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_keys_to_action to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_keys_to_action` for environment variables or `env.get_wrapper_attr('get_keys_to_action')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\josh\anaconda3\Lib\site-packages\gymnasium\utils\passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       7 import os
#       8 env = gym.make('ALE/Alien-v5', render_mode='rgb_array')
# ----> 9 play(env, zoom=3)
#
# File ~\anaconda3\Lib\site-packages\gymnasium\utils\play.py:291, in play(env, transpose, fps, zoom, callback, keys_to_action, seed, noop)
#     288         game.process_event(event)
#     290     pygame.display.flip()
# --> 291     clock.tick(fps)
#     292 pygame.quit()
#
# KeyboardInterrupt:

# %%
import gymnasium as gym
from stable_baselines3 import A2C

# Create the Gym environment
env = gym.make("ALE/Boxing-v5")

vec_env = model.get_env()
obs = vec_env.reset()

vec_env.render("human")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       4 # Create the Gym environment
#       5 env = gym.make("ALE/Boxing-v5")
# ----> 7 vec_env = model.get_env()
#       8 obs = vec_env.reset()
#      10 vec_env.render("human")
#
# NameError: name 'model' is not defined

# %%
env.close()

# %%
vec_env = model.get_env()
obs = vec_env.reset()
while True:
    action, _states = model.predict(obs, deterministic=False)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 4
#       2 while True:
#       3     action = env.action_space.sample()
# ----> 4     obs, rewards, terminated, truncated, info = env.step(action)
#       5     env.render()
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:33, in VecFrameStack.step_wait(self)
#      30 def step_wait(
#      31     self,
#      32 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 33     observations, rewards, dones, infos = self.venv.step_wait()
#      34     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      35     return observations, rewards, dones, infos
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
#      58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# IndexError: invalid index to scalar variable.

# %%
env = make_atari_env("ALE/Boxing-v5", n_envs=1)
env = VecFrameStack(env, n_stack=1)

# %%
env.observation_space.shape
# Out:
# (84, 84, 16)

# %%
model = A2C("CnnPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 373      |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 100      |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.856   |
# |    explained_variance | 0.0211   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.28    |
# |    value_loss         | 1.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 371      |
# |    ep_rew_mean        | 12.8     |
# | time/                 |          |
# |    fps                | 113      |
# |    iterations         | 200      |
# |    time_elapsed       | 141      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | 0.324    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0117   |
# |    value_loss         | 0.174    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 363      |
# |    ep_rew_mean        | 12.6     |
# | time/                 |          |
# |    fps                | 113      |
# |    iterations         | 300      |
# |    time_elapsed       | 210      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0642  |
# |    value_loss         | 0.625    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 361      |
# |    ep_rew_mean        | 12.6     |
# | time/                 |          |
# |    fps                | 113      |
# |    iterations         | 400      |
# |    time_elapsed       | 282      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.0857   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.467   |
# |    value_loss         | 1.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 367      |
# |    ep_rew_mean        | 13.3     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 500      |
# |    time_elapsed       | 356      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.972   |
# |    explained_variance | 0.353    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0524   |
# |    value_loss         | 0.254    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 381      |
# |    ep_rew_mean        | 13.6     |
# | time/                 |          |
# |    fps                | 113      |
# |    iterations         | 600      |
# |    time_elapsed       | 421      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.807   |
# |    explained_variance | 0.419    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0303  |
# |    value_loss         | 0.699    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 380      |
# |    ep_rew_mean        | 13.7     |
# | time/                 |          |
# |    fps                | 114      |
# |    iterations         | 700      |
# |    time_elapsed       | 488      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.932   |
# |    explained_variance | 0.143    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.173    |
# |    value_loss         | 0.646    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 397      |
# |    ep_rew_mean        | 14.8     |
# | time/                 |          |
# |    fps                | 115      |
# |    iterations         | 800      |
# |    time_elapsed       | 555      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.996   |
# |    explained_variance | 0.116    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.198    |
# |    value_loss         | 0.328    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 406      |
# |    ep_rew_mean        | 15.1     |
# | time/                 |          |
# |    fps                | 115      |
# |    iterations         | 900      |
# |    time_elapsed       | 623      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.879   |
# |    explained_variance | 0.254    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0994   |
# |    value_loss         | 0.239    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 417      |
# |    ep_rew_mean        | 15.6     |
# | time/                 |          |
# |    fps                | 114      |
# |    iterations         | 1000     |
# |    time_elapsed       | 698      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.911   |
# |    explained_variance | 0.0333   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00652  |
# |    value_loss         | 1.88     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 400      |
# |    ep_rew_mean        | 14.9     |
# | time/                 |          |
# |    fps                | 111      |
# |    iterations         | 1100     |
# |    time_elapsed       | 785      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.864   |
# |    explained_variance | 0.653    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0491  |
# |    value_loss         | 0.178    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 418      |
# |    ep_rew_mean        | 15.5     |
# | time/                 |          |
# |    fps                | 110      |
# |    iterations         | 1200     |
# |    time_elapsed       | 869      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.803   |
# |    explained_variance | 0.688    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0834   |
# |    value_loss         | 0.143    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 441      |
# |    ep_rew_mean        | 17.4     |
# | time/                 |          |
# |    fps                | 110      |
# |    iterations         | 1300     |
# |    time_elapsed       | 941      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.88    |
# |    explained_variance | 0.332    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0281  |
# |    value_loss         | 1.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 464      |
# |    ep_rew_mean        | 17.4     |
# | time/                 |          |
# |    fps                | 110      |
# |    iterations         | 1400     |
# |    time_elapsed       | 1014     |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.668   |
# |    explained_variance | 0.361    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0504  |
# |    value_loss         | 3.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | 19.4     |
# | time/                 |          |
# |    fps                | 110      |
# |    iterations         | 1500     |
# |    time_elapsed       | 1083     |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.704   |
# |    explained_variance | 0.643    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.0637   |
# |    value_loss         | 0.262    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 525      |
# |    ep_rew_mean        | 21.4     |
# | time/                 |          |
# |    fps                | 111      |
# |    iterations         | 1600     |
# |    time_elapsed       | 1148     |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.568   |
# |    explained_variance | 0.0847   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.02     |
# |    value_loss         | 2.48     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 532      |
# |    ep_rew_mean        | 21.1     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 1700     |
# |    time_elapsed       | 1214     |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.605   |
# |    explained_variance | 0.665    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.0609  |
# |    value_loss         | 0.47     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 559      |
# |    ep_rew_mean        | 22.5     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 1800     |
# |    time_elapsed       | 1282     |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.415   |
# |    explained_variance | 0.347    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.277   |
# |    value_loss         | 2.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 596      |
# |    ep_rew_mean        | 23.4     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 1900     |
# |    time_elapsed       | 1349     |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.547   |
# |    explained_variance | 0.276    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.141   |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 658      |
# |    ep_rew_mean        | 24.2     |
# | time/                 |          |
# |    fps                | 113      |
# |    iterations         | 2000     |
# |    time_elapsed       | 1414     |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -0.328   |
# |    explained_variance | 0.281    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0896   |
# |    value_loss         | 0.574    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 722      |
# |    ep_rew_mean        | 24.5     |
# | time/                 |          |
# |    fps                | 113      |
# |    iterations         | 2100     |
# |    time_elapsed       | 1477     |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -0.43    |
# |    explained_variance | 0.576    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.0196   |
# |    value_loss         | 0.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 746      |
# |    ep_rew_mean        | 25.2     |
# | time/                 |          |
# |    fps                | 114      |
# |    iterations         | 2200     |
# |    time_elapsed       | 1543     |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -0.246   |
# |    explained_variance | 0.257    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.121   |
# |    value_loss         | 1.49     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 781      |
# |    ep_rew_mean        | 25.5     |
# | time/                 |          |
# |    fps                | 114      |
# |    iterations         | 2300     |
# |    time_elapsed       | 1607     |
# |    total_timesteps    | 184000   |
# | train/                |          |
# |    entropy_loss       | -0.368   |
# |    explained_variance | 0.64     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.147   |
# |    value_loss         | 1.36     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 787      |
# |    ep_rew_mean        | 25.8     |
# | time/                 |          |
# |    fps                | 114      |
# |    iterations         | 2400     |
# |    time_elapsed       | 1673     |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | 0.521    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.06    |
# |    value_loss         | 1.9      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 856      |
# |    ep_rew_mean        | 27.6     |
# | time/                 |          |
# |    fps                | 115      |
# |    iterations         | 2500     |
# |    time_elapsed       | 1737     |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -0.153   |
# |    explained_variance | 0.489    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.118   |
# |    value_loss         | 2.42     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 873      |
# |    ep_rew_mean        | 28.9     |
# | time/                 |          |
# |    fps                | 115      |
# |    iterations         | 2600     |
# |    time_elapsed       | 1803     |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | -0.213   |
# |    explained_variance | 0.793    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.0145   |
# |    value_loss         | 0.727    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 860      |
# |    ep_rew_mean        | 29.6     |
# | time/                 |          |
# |    fps                | 115      |
# |    iterations         | 2700     |
# |    time_elapsed       | 1868     |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -0.161   |
# |    explained_variance | 0.353    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0261  |
# |    value_loss         | 1.72     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 838      |
# |    ep_rew_mean        | 30.5     |
# | time/                 |          |
# |    fps                | 115      |
# |    iterations         | 2800     |
# |    time_elapsed       | 1936     |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | -0.0963  |
# |    explained_variance | 0.649    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0143  |
# |    value_loss         | 0.804    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 873      |
# |    ep_rew_mean        | 31.8     |
# | time/                 |          |
# |    fps                | 116      |
# |    iterations         | 2900     |
# |    time_elapsed       | 1998     |
# |    total_timesteps    | 232000   |
# | train/                |          |
# |    entropy_loss       | -0.178   |
# |    explained_variance | 0.874    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0235   |
# |    value_loss         | 0.511    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 900      |
# |    ep_rew_mean        | 33       |
# | time/                 |          |
# |    fps                | 116      |
# |    iterations         | 3000     |
# |    time_elapsed       | 2062     |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -0.122   |
# |    explained_variance | 0.774    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0032   |
# |    value_loss         | 1.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 908      |
# |    ep_rew_mean        | 33.1     |
# | time/                 |          |
# |    fps                | 116      |
# |    iterations         | 3100     |
# |    time_elapsed       | 2126     |
# |    total_timesteps    | 248000   |
# | train/                |          |
# |    entropy_loss       | -0.0911  |
# |    explained_variance | 0.71     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0206  |
# |    value_loss         | 2.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 931      |
# |    ep_rew_mean        | 32.9     |
# | time/                 |          |
# |    fps                | 75       |
# |    iterations         | 3200     |
# |    time_elapsed       | 3370     |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | -0.141   |
# |    explained_variance | 0.516    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0246   |
# |    value_loss         | 1.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 904      |
# |    ep_rew_mean        | 31.7     |
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 3300     |
# |    time_elapsed       | 3433     |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -0.17    |
# |    explained_variance | 0.523    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00251  |
# |    value_loss         | 2.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 872      |
# |    ep_rew_mean        | 30.3     |
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 3400     |
# |    time_elapsed       | 3500     |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -0.233   |
# |    explained_variance | 0.869    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.566    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 838      |
# |    ep_rew_mean        | 31       |
# | time/                 |          |
# |    fps                | 78       |
# |    iterations         | 3500     |
# |    time_elapsed       | 3562     |
# |    total_timesteps    | 280000   |
# | train/                |          |
# |    entropy_loss       | -0.195   |
# |    explained_variance | 0.668    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0359   |
# |    value_loss         | 1.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 857      |
# |    ep_rew_mean        | 31.9     |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 3600     |
# |    time_elapsed       | 3624     |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.417   |
# |    explained_variance | 0.59     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.111    |
# |    value_loss         | 1.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 829      |
# |    ep_rew_mean        | 30.7     |
# | time/                 |          |
# |    fps                | 80       |
# |    iterations         | 3700     |
# |    time_elapsed       | 3690     |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -0.232   |
# |    explained_variance | 0.656    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0798  |
# |    value_loss         | 2.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 796      |
# |    ep_rew_mean        | 29.7     |
# | time/                 |          |
# |    fps                | 49       |
# |    iterations         | 3800     |
# |    time_elapsed       | 6188     |
# |    total_timesteps    | 304000   |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | 0.422    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.155   |
# |    value_loss         | 2.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 778      |
# |    ep_rew_mean        | 30.5     |
# | time/                 |          |
# |    fps                | 49       |
# |    iterations         | 3900     |
# |    time_elapsed       | 6253     |
# |    total_timesteps    | 312000   |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | 0.773    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00969  |
# |    value_loss         | 1.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 757      |
# |    ep_rew_mean        | 31.1     |
# | time/                 |          |
# |    fps                | 50       |
# |    iterations         | 4000     |
# |    time_elapsed       | 6318     |
# |    total_timesteps    | 320000   |
# | train/                |          |
# |    entropy_loss       | -0.17    |
# |    explained_variance | 0.727    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0532  |
# |    value_loss         | 0.802    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 772      |
# |    ep_rew_mean        | 30.9     |
# | time/                 |          |
# |    fps                | 51       |
# |    iterations         | 4100     |
# |    time_elapsed       | 6383     |
# |    total_timesteps    | 328000   |
# | train/                |          |
# |    entropy_loss       | -0.191   |
# |    explained_variance | 0.769    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0799  |
# |    value_loss         | 0.604    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 796      |
# |    ep_rew_mean        | 32       |
# | time/                 |          |
# |    fps                | 52       |
# |    iterations         | 4200     |
# |    time_elapsed       | 6447     |
# |    total_timesteps    | 336000   |
# | train/                |          |
# |    entropy_loss       | -0.0975  |
# |    explained_variance | 0.766    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0964  |
# |    value_loss         | 1.3      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 806      |
# |    ep_rew_mean        | 32.6     |
# | time/                 |          |
# |    fps                | 52       |
# |    iterations         | 4300     |
# |    time_elapsed       | 6514     |
# |    total_timesteps    | 344000   |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0649  |
# |    value_loss         | 0.405    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 868      |
# |    ep_rew_mean        | 34.4     |
# | time/                 |          |
# |    fps                | 53       |
# |    iterations         | 4400     |
# |    time_elapsed       | 6580     |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -0.085   |
# |    explained_variance | 0.944    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.0293   |
# |    value_loss         | 0.22     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 900      |
# |    ep_rew_mean        | 34.4     |
# | time/                 |          |
# |    fps                | 54       |
# |    iterations         | 4500     |
# |    time_elapsed       | 6646     |
# |    total_timesteps    | 360000   |
# | train/                |          |
# |    entropy_loss       | -0.141   |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0548   |
# |    value_loss         | 0.501    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 885      |
# |    ep_rew_mean        | 35.8     |
# | time/                 |          |
# |    fps                | 54       |
# |    iterations         | 4600     |
# |    time_elapsed       | 6716     |
# |    total_timesteps    | 368000   |
# | train/                |          |
# |    entropy_loss       | -0.107   |
# |    explained_variance | 0.79     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0143   |
# |    value_loss         | 1.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 840      |
# |    ep_rew_mean        | 36.7     |
# | time/                 |          |
# |    fps                | 55       |
# |    iterations         | 4700     |
# |    time_elapsed       | 6783     |
# |    total_timesteps    | 376000   |
# | train/                |          |
# |    entropy_loss       | -0.119   |
# |    explained_variance | 0.964    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0283  |
# |    value_loss         | 0.109    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 834      |
# |    ep_rew_mean        | 38.4     |
# | time/                 |          |
# |    fps                | 56       |
# |    iterations         | 4800     |
# |    time_elapsed       | 6850     |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -0.132   |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0283  |
# |    value_loss         | 0.358    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 824      |
# |    ep_rew_mean        | 38.1     |
# | time/                 |          |
# |    fps                | 56       |
# |    iterations         | 4900     |
# |    time_elapsed       | 6916     |
# |    total_timesteps    | 392000   |
# | train/                |          |
# |    entropy_loss       | -0.179   |
# |    explained_variance | 0.673    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0545  |
# |    value_loss         | 1.23     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 798      |
# |    ep_rew_mean        | 34.7     |
# | time/                 |          |
# |    fps                | 57       |
# |    iterations         | 5000     |
# |    time_elapsed       | 6985     |
# |    total_timesteps    | 400000   |
# | train/                |          |
# |    entropy_loss       | -0.195   |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0104   |
# |    value_loss         | 0.792    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 785      |
# |    ep_rew_mean        | 32.2     |
# | time/                 |          |
# |    fps                | 57       |
# |    iterations         | 5100     |
# |    time_elapsed       | 7052     |
# |    total_timesteps    | 408000   |
# | train/                |          |
# |    entropy_loss       | -0.0973  |
# |    explained_variance | 0.668    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.126   |
# |    value_loss         | 1.92     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 815      |
# |    ep_rew_mean        | 33.5     |
# | time/                 |          |
# |    fps                | 58       |
# |    iterations         | 5200     |
# |    time_elapsed       | 7122     |
# |    total_timesteps    | 416000   |
# | train/                |          |
# |    entropy_loss       | -0.166   |
# |    explained_variance | 0.915    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0178  |
# |    value_loss         | 0.373    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 815      |
# |    ep_rew_mean        | 34.9     |
# | time/                 |          |
# |    fps                | 58       |
# |    iterations         | 5300     |
# |    time_elapsed       | 7192     |
# |    total_timesteps    | 424000   |
# | train/                |          |
# |    entropy_loss       | -0.224   |
# |    explained_variance | 0.746    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.37    |
# |    value_loss         | 2.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 822      |
# |    ep_rew_mean        | 35.1     |
# | time/                 |          |
# |    fps                | 59       |
# |    iterations         | 5400     |
# |    time_elapsed       | 7285     |
# |    total_timesteps    | 432000   |
# | train/                |          |
# |    entropy_loss       | -0.169   |
# |    explained_variance | 0.694    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0893  |
# |    value_loss         | 1.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 846      |
# |    ep_rew_mean        | 36       |
# | time/                 |          |
# |    fps                | 59       |
# |    iterations         | 5500     |
# |    time_elapsed       | 7375     |
# |    total_timesteps    | 440000   |
# | train/                |          |
# |    entropy_loss       | -0.114   |
# |    explained_variance | 0.89     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.0728  |
# |    value_loss         | 0.358    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 870      |
# |    ep_rew_mean        | 35.8     |
# | time/                 |          |
# |    fps                | 60       |
# |    iterations         | 5600     |
# |    time_elapsed       | 7461     |
# |    total_timesteps    | 448000   |
# | train/                |          |
# |    entropy_loss       | -0.138   |
# |    explained_variance | 0.911    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0408   |
# |    value_loss         | 0.402    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 884      |
# |    ep_rew_mean        | 36.2     |
# | time/                 |          |
# |    fps                | 60       |
# |    iterations         | 5700     |
# |    time_elapsed       | 7547     |
# |    total_timesteps    | 456000   |
# | train/                |          |
# |    entropy_loss       | -0.0909  |
# |    explained_variance | 0.832    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0258  |
# |    value_loss         | 0.621    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 871      |
# |    ep_rew_mean        | 36.1     |
# | time/                 |          |
# |    fps                | 60       |
# |    iterations         | 5800     |
# |    time_elapsed       | 7629     |
# |    total_timesteps    | 464000   |
# | train/                |          |
# |    entropy_loss       | -0.0986  |
# |    explained_variance | 0.921    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.00188  |
# |    value_loss         | 0.324    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 888      |
# |    ep_rew_mean        | 36       |
# | time/                 |          |
# |    fps                | 61       |
# |    iterations         | 5900     |
# |    time_elapsed       | 7711     |
# |    total_timesteps    | 472000   |
# | train/                |          |
# |    entropy_loss       | -0.0975  |
# |    explained_variance | 0.838    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.0283  |
# |    value_loss         | 1.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 877      |
# |    ep_rew_mean        | 35.4     |
# | time/                 |          |
# |    fps                | 61       |
# |    iterations         | 6000     |
# |    time_elapsed       | 7793     |
# |    total_timesteps    | 480000   |
# | train/                |          |
# |    entropy_loss       | -0.187   |
# |    explained_variance | 0.875    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0223   |
# |    value_loss         | 0.316    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 857      |
# |    ep_rew_mean        | 35.3     |
# | time/                 |          |
# |    fps                | 61       |
# |    iterations         | 6100     |
# |    time_elapsed       | 7875     |
# |    total_timesteps    | 488000   |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | 0.733    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0389  |
# |    value_loss         | 0.916    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 839      |
# |    ep_rew_mean        | 34.9     |
# | time/                 |          |
# |    fps                | 62       |
# |    iterations         | 6200     |
# |    time_elapsed       | 7945     |
# |    total_timesteps    | 496000   |
# | train/                |          |
# |    entropy_loss       | -0.112   |
# |    explained_variance | 0.791    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0192  |
# |    value_loss         | 1.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 870      |
# |    ep_rew_mean        | 36.3     |
# | time/                 |          |
# |    fps                | 62       |
# |    iterations         | 6300     |
# |    time_elapsed       | 8017     |
# |    total_timesteps    | 504000   |
# | train/                |          |
# |    entropy_loss       | -0.16    |
# |    explained_variance | 0.902    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0561  |
# |    value_loss         | 0.293    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 893      |
# |    ep_rew_mean        | 36.3     |
# | time/                 |          |
# |    fps                | 63       |
# |    iterations         | 6400     |
# |    time_elapsed       | 8084     |
# |    total_timesteps    | 512000   |
# | train/                |          |
# |    entropy_loss       | -0.101   |
# |    explained_variance | 0.819    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.00584 |
# |    value_loss         | 0.285    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 929      |
# |    ep_rew_mean        | 36.9     |
# | time/                 |          |
# |    fps                | 63       |
# |    iterations         | 6500     |
# |    time_elapsed       | 8150     |
# |    total_timesteps    | 520000   |
# | train/                |          |
# |    entropy_loss       | -0.0828  |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0129  |
# |    value_loss         | 0.876    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 940      |
# |    ep_rew_mean        | 37.6     |
# | time/                 |          |
# |    fps                | 64       |
# |    iterations         | 6600     |
# |    time_elapsed       | 8216     |
# |    total_timesteps    | 528000   |
# | train/                |          |
# |    entropy_loss       | -0.117   |
# |    explained_variance | 0.828    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0128  |
# |    value_loss         | 0.499    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 975      |
# |    ep_rew_mean        | 38.4     |
# | time/                 |          |
# |    fps                | 64       |
# |    iterations         | 6700     |
# |    time_elapsed       | 8281     |
# |    total_timesteps    | 536000   |
# | train/                |          |
# |    entropy_loss       | -0.134   |
# |    explained_variance | 0.656    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0117  |
# |    value_loss         | 1.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 984      |
# |    ep_rew_mean        | 39.3     |
# | time/                 |          |
# |    fps                | 65       |
# |    iterations         | 6800     |
# |    time_elapsed       | 8347     |
# |    total_timesteps    | 544000   |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | 0.895    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00689 |
# |    value_loss         | 0.243    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 988      |
# |    ep_rew_mean        | 40.9     |
# | time/                 |          |
# |    fps                | 65       |
# |    iterations         | 6900     |
# |    time_elapsed       | 8414     |
# |    total_timesteps    | 552000   |
# | train/                |          |
# |    entropy_loss       | -0.125   |
# |    explained_variance | 0.914    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.00377  |
# |    value_loss         | 0.505    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 950      |
# |    ep_rew_mean        | 42.8     |
# | time/                 |          |
# |    fps                | 65       |
# |    iterations         | 7000     |
# |    time_elapsed       | 8485     |
# |    total_timesteps    | 560000   |
# | train/                |          |
# |    entropy_loss       | -0.105   |
# |    explained_variance | 0.609    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.0198  |
# |    value_loss         | 2.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 917      |
# |    ep_rew_mean        | 42.8     |
# | time/                 |          |
# |    fps                | 66       |
# |    iterations         | 7100     |
# |    time_elapsed       | 8550     |
# |    total_timesteps    | 568000   |
# | train/                |          |
# |    entropy_loss       | -0.0944  |
# |    explained_variance | 0.642    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.0304  |
# |    value_loss         | 1.69     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 904      |
# |    ep_rew_mean        | 44.2     |
# | time/                 |          |
# |    fps                | 66       |
# |    iterations         | 7200     |
# |    time_elapsed       | 8616     |
# |    total_timesteps    | 576000   |
# | train/                |          |
# |    entropy_loss       | -0.116   |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.0147   |
# |    value_loss         | 0.218    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 896      |
# |    ep_rew_mean        | 45.5     |
# | time/                 |          |
# |    fps                | 67       |
# |    iterations         | 7300     |
# |    time_elapsed       | 8682     |
# |    total_timesteps    | 584000   |
# | train/                |          |
# |    entropy_loss       | -0.108   |
# |    explained_variance | 0.526    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.0883  |
# |    value_loss         | 2.42     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 880      |
# |    ep_rew_mean        | 46.5     |
# | time/                 |          |
# |    fps                | 67       |
# |    iterations         | 7400     |
# |    time_elapsed       | 8758     |
# |    total_timesteps    | 592000   |
# | train/                |          |
# |    entropy_loss       | -0.084   |
# |    explained_variance | 0.9      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.0312  |
# |    value_loss         | 0.595    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 898      |
# |    ep_rew_mean        | 45.7     |
# | time/                 |          |
# |    fps                | 67       |
# |    iterations         | 7500     |
# |    time_elapsed       | 8842     |
# |    total_timesteps    | 600000   |
# | train/                |          |
# |    entropy_loss       | -0.0543  |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.00841 |
# |    value_loss         | 0.166    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 892      |
# |    ep_rew_mean        | 46.3     |
# | time/                 |          |
# |    fps                | 68       |
# |    iterations         | 7600     |
# |    time_elapsed       | 8913     |
# |    total_timesteps    | 608000   |
# | train/                |          |
# |    entropy_loss       | -0.095   |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.033    |
# |    value_loss         | 0.403    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 889      |
# |    ep_rew_mean        | 46.8     |
# | time/                 |          |
# ...
# |    entropy_loss       | -0.0658  |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9999     |
# |    policy_loss        | -0.0461  |
# |    value_loss         | 0.423    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 904      |
# |    ep_rew_mean        | 46.1     |
# | time/                 |          |
# |    fps                | 75       |
# |    iterations         | 10100    |
# |    time_elapsed       | 10714    |
# |    total_timesteps    | 808000   |
# | train/                |          |
# |    entropy_loss       | -0.0536  |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10099    |
# |    policy_loss        | 0.0161   |
# |    value_loss         | 0.119    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 892      |
# |    ep_rew_mean        | 46.2     |
# | time/                 |          |
# |    fps                | 75       |
# |    iterations         | 10200    |
# |    time_elapsed       | 10780    |
# |    total_timesteps    | 816000   |
# | train/                |          |
# |    entropy_loss       | -0.04    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10199    |
# |    policy_loss        | -0.0116  |
# |    value_loss         | 0.0875   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 869      |
# |    ep_rew_mean        | 43.7     |
# | time/                 |          |
# |    fps                | 75       |
# |    iterations         | 10300    |
# |    time_elapsed       | 10847    |
# |    total_timesteps    | 824000   |
# | train/                |          |
# |    entropy_loss       | -0.0627  |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10299    |
# |    policy_loss        | 0.0374   |
# |    value_loss         | 0.293    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 871      |
# |    ep_rew_mean        | 42.2     |
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 10400    |
# |    time_elapsed       | 10916    |
# |    total_timesteps    | 832000   |
# | train/                |          |
# |    entropy_loss       | -0.0891  |
# |    explained_variance | 0.721    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10399    |
# |    policy_loss        | -0.157   |
# |    value_loss         | 1.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 906      |
# |    ep_rew_mean        | 47.6     |
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 10500    |
# |    time_elapsed       | 10985    |
# |    total_timesteps    | 840000   |
# | train/                |          |
# |    entropy_loss       | -0.0965  |
# |    explained_variance | 0.924    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10499    |
# |    policy_loss        | 0.0182   |
# |    value_loss         | 0.294    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 898      |
# |    ep_rew_mean        | 56.1     |
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 10600    |
# |    time_elapsed       | 11055    |
# |    total_timesteps    | 848000   |
# | train/                |          |
# |    entropy_loss       | -0.077   |
# |    explained_variance | 0.964    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10599    |
# |    policy_loss        | -0.0394  |
# |    value_loss         | 0.367    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 889      |
# |    ep_rew_mean        | 58.1     |
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 10700    |
# |    time_elapsed       | 11122    |
# |    total_timesteps    | 856000   |
# | train/                |          |
# |    entropy_loss       | -0.0411  |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10699    |
# |    policy_loss        | -0.00537 |
# |    value_loss         | 0.262    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 898      |
# |    ep_rew_mean        | 56.1     |
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 10800    |
# |    time_elapsed       | 11189    |
# |    total_timesteps    | 864000   |
# | train/                |          |
# |    entropy_loss       | -0.134   |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10799    |
# |    policy_loss        | 0.088    |
# |    value_loss         | 0.897    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 899      |
# |    ep_rew_mean        | 58       |
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 10900    |
# |    time_elapsed       | 11258    |
# |    total_timesteps    | 872000   |
# | train/                |          |
# |    entropy_loss       | -0.0694  |
# |    explained_variance | 0.906    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10899    |
# |    policy_loss        | -0.091   |
# |    value_loss         | 0.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 874      |
# |    ep_rew_mean        | 63       |
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 11000    |
# |    time_elapsed       | 11327    |
# |    total_timesteps    | 880000   |
# | train/                |          |
# |    entropy_loss       | -0.0693  |
# |    explained_variance | 0.849    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10999    |
# |    policy_loss        | -0.0337  |
# |    value_loss         | 1.48     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 853      |
# |    ep_rew_mean        | 64.7     |
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 11100    |
# |    time_elapsed       | 11394    |
# |    total_timesteps    | 888000   |
# | train/                |          |
# |    entropy_loss       | -0.0664  |
# |    explained_variance | 0.894    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11099    |
# |    policy_loss        | 0.00241  |
# |    value_loss         | 0.57     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 900      |
# |    ep_rew_mean        | 62.5     |
# | time/                 |          |
# |    fps                | 78       |
# |    iterations         | 11200    |
# |    time_elapsed       | 11461    |
# |    total_timesteps    | 896000   |
# | train/                |          |
# |    entropy_loss       | -0.0515  |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11199    |
# |    policy_loss        | -0.0127  |
# |    value_loss         | 0.141    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 902      |
# |    ep_rew_mean        | 63       |
# | time/                 |          |
# |    fps                | 78       |
# |    iterations         | 11300    |
# |    time_elapsed       | 11530    |
# |    total_timesteps    | 904000   |
# | train/                |          |
# |    entropy_loss       | -0.072   |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11299    |
# |    policy_loss        | 0.0768   |
# |    value_loss         | 0.32     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 886      |
# |    ep_rew_mean        | 63.9     |
# | time/                 |          |
# |    fps                | 78       |
# |    iterations         | 11400    |
# |    time_elapsed       | 11605    |
# |    total_timesteps    | 912000   |
# | train/                |          |
# |    entropy_loss       | -0.107   |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11399    |
# |    policy_loss        | 0.0304   |
# |    value_loss         | 0.45     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 852      |
# |    ep_rew_mean        | 65.6     |
# | time/                 |          |
# |    fps                | 78       |
# |    iterations         | 11500    |
# |    time_elapsed       | 11676    |
# |    total_timesteps    | 920000   |
# | train/                |          |
# |    entropy_loss       | -0.0978  |
# |    explained_variance | 0.906    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11499    |
# |    policy_loss        | -0.00667 |
# |    value_loss         | 0.858    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 847      |
# |    ep_rew_mean        | 64.5     |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 11600    |
# |    time_elapsed       | 11743    |
# |    total_timesteps    | 928000   |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | 0.918    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11599    |
# |    policy_loss        | -0.0171  |
# |    value_loss         | 0.664    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 856      |
# |    ep_rew_mean        | 59.8     |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 11700    |
# |    time_elapsed       | 11814    |
# |    total_timesteps    | 936000   |
# | train/                |          |
# |    entropy_loss       | -0.0944  |
# |    explained_variance | 0.925    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11699    |
# |    policy_loss        | 0.0964   |
# |    value_loss         | 0.326    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 879      |
# |    ep_rew_mean        | 57.3     |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 11800    |
# |    time_elapsed       | 11891    |
# |    total_timesteps    | 944000   |
# | train/                |          |
# |    entropy_loss       | -0.0643  |
# |    explained_variance | 0.92     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11799    |
# |    policy_loss        | -0.0132  |
# |    value_loss         | 0.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 909      |
# |    ep_rew_mean        | 59.2     |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 11900    |
# |    time_elapsed       | 11979    |
# |    total_timesteps    | 952000   |
# | train/                |          |
# |    entropy_loss       | -0.048   |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11899    |
# |    policy_loss        | 0.00649  |
# |    value_loss         | 0.599    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 955      |
# |    ep_rew_mean        | 64       |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 12000    |
# |    time_elapsed       | 12055    |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | 0.912    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11999    |
# |    policy_loss        | -0.0362  |
# |    value_loss         | 0.845    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 957      |
# |    ep_rew_mean        | 61       |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 12100    |
# |    time_elapsed       | 12133    |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | 0.729    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12099    |
# |    policy_loss        | 0.0396   |
# |    value_loss         | 0.565    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 957      |
# |    ep_rew_mean        | 60.8     |
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 12200    |
# |    time_elapsed       | 12204    |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -0.0653  |
# |    explained_variance | 0.87     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12199    |
# |    policy_loss        | 0.0828   |
# |    value_loss         | 0.647    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 916      |
# |    ep_rew_mean        | 59       |
# | time/                 |          |
# |    fps                | 80       |
# |    iterations         | 12300    |
# |    time_elapsed       | 12272    |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | -0.0983  |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12299    |
# |    policy_loss        | -0.0225  |
# |    value_loss         | 1.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 903      |
# |    ep_rew_mean        | 67.2     |
# | time/                 |          |
# |    fps                | 80       |
# |    iterations         | 12400    |
# |    time_elapsed       | 12338    |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -0.0502  |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12399    |
# |    policy_loss        | -0.0225  |
# |    value_loss         | 0.491    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 931      |
# |    ep_rew_mean        | 64.4     |
# | time/                 |          |
# |    fps                | 80       |
# |    iterations         | 12500    |
# |    time_elapsed       | 12405    |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -0.0204  |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12499    |
# |    policy_loss        | 0.00634  |
# |    value_loss         | 0.448    |
# ------------------------------------

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'a2c_boxer')

# %%
env = make_atari_env("ALE/Boxing-v5", n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=1)

# %%
env = make_atari_env('ALE/Boxing-v5', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=16)

# %%
env = gym.make("ALE/Boxing-v5", render_mode='human')

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 model = A2C.load(a2c_path, env)
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\base_class.py:714, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     712 env = cls._wrap_env(env, data["verbose"])
#     713 # Check if given env is valid
# --> 714 check_for_correct_spaces(env, data["observation_space"], data["action_space"])
#     715 # Discard `_last_obs`, this will force the env to reset before training
#     716 # See issue https://github.com/DLR-RM/stable-baselines3/issues/597
#     717 if force_reset and data is not None:
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\utils.py:229, in check_for_correct_spaces(env, observation_space, action_space)
#     217 """
#     218 Checks that the environment has same spaces as provided ones. Used by BaseAlgorithm to check if
#     219 spaces match after loading the model with given env.
#    (...)
#     226 :param action_space: Action space to check against
#     227 """
#     228 if observation_space != env.observation_space:
# --> 229     raise ValueError(f"Observation spaces do not match: {observation_space} != {env.observation_space}")
#     230 if action_space != env.action_space:
#     231     raise ValueError(f"Action spaces do not match: {action_space} != {env.action_space}")
#
# ValueError: Observation spaces do not match: Box(0, 255, (12, 84, 84), uint8) != Box(0, 255, (3, 210, 160), uint8)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 3
#       1 obs, info = env.reset()
#       2 while True:
# ----> 3     action = model.predict(obs)
#       4     obs, rewards, terminated, truncated, info = vec_env.step(action)
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\base_class.py:553, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     533 def predict(
#     534     self,
#     535     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     538     deterministic: bool = False,
#     539 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     540     """
#     541     Get the policy action from an observation (and optional hidden state).
#     542     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     551         (used in recurrent policies)
#     552     """
# --> 553     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\policies.py:363, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     354 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     355     raise ValueError(
#     356         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     357         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)
#     360         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     361     )
# --> 363 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     365 with th.no_grad():
#     366     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\policies.py:270, in BaseModel.obs_to_tensor(self, observation)
#     266     observation = np.array(observation)
#     268 if not isinstance(observation, dict):
#     269     # Dict obs need to be handled separately
# --> 270     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     271     # Add batch dimension if needed
#     272     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\utils.py:399, in is_vectorized_observation(observation, observation_space)
#     397 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     398     if isinstance(observation_space, space_type):
# --> 399         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     400 else:
#     401     # for-else happens if no break is called
#     402     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\utils.py:266, in is_vectorized_box_observation(observation, observation_space)
#     264     return True
#     265 else:
# --> 266     raise ValueError(
#     267         f"Error: Unexpected observation shape {observation.shape} for "
#     268         + f"Box environment, please use {observation_space.shape} "
#     269         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     270     )
#
# ValueError: Error: Unexpected observation shape (210, 160, 3) for Box environment, please use (12, 84, 84) or (n_env, 12, 84, 84) for the observation shape.

# %%
env.close()

# %%
model.save(a2c_path)

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'Frogger')

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 model = A2C.load(a2c_path, env)
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\base_class.py:714, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     712 env = cls._wrap_env(env, data["verbose"])
#     713 # Check if given env is valid
# --> 714 check_for_correct_spaces(env, data["observation_space"], data["action_space"])
#     715 # Discard `_last_obs`, this will force the env to reset before training
#     716 # See issue https://github.com/DLR-RM/stable-baselines3/issues/597
#     717 if force_reset and data is not None:
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\utils.py:231, in check_for_correct_spaces(env, observation_space, action_space)
#     229     raise ValueError(f"Observation spaces do not match: {observation_space} != {env.observation_space}")
#     230 if action_space != env.action_space:
# --> 231     raise ValueError(f"Action spaces do not match: {action_space} != {env.action_space}")
#
# ValueError: Action spaces do not match: Discrete(5) != Discrete(18)
