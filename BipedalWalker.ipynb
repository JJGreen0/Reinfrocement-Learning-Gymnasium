# %%
import gymnasium as gym
import time
from stable_baselines3 import PPO

# %%
env = gym.make("LunarLander-v2", render_mode="rgb_array")

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.6     |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    fps             | 780      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95          |
# |    ep_rew_mean          | -193        |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009739238 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00851     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 531         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 1.92e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.9        |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006715378 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0543     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 416         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 1.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.3        |
# |    ep_rew_mean          | -188        |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008521573 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.049      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 243         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 941         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.4        |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 449         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008964051 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00526    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 443         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 1.57e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.3         |
# |    ep_rew_mean          | -163         |
# | time/                   |              |
# |    fps                  | 445          |
# |    iterations           | 6            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0063313926 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00018      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 210          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 850          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -154        |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009223804 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0102     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 435         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 799         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 8           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010623548 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -3.12e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00951    |
# |    value_loss           | 308         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 449         |
# |    iterations           | 9           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012670318 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00112    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 202         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 397         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 113        |
# |    ep_rew_mean          | -105       |
# | time/                   |            |
# |    fps                  | 442        |
# |    iterations           | 10         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00938011 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | -8.38e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 166        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 398        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 120        |
# |    ep_rew_mean          | -99.4      |
# | time/                   |            |
# |    fps                  | 442        |
# |    iterations           | 11         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00854948 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | -1.9e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 135        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.014     |
# |    value_loss           | 228        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 125          |
# |    ep_rew_mean          | -89.9        |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 12           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0062579047 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -3.99e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 162          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00821     |
# |    value_loss           | 316          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 131          |
# |    ep_rew_mean          | -80.5        |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 13           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0150896935 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.000139    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00716     |
# |    value_loss           | 272          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | -80.3        |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 14           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0062305126 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | -2.44e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 140          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00339     |
# |    value_loss           | 311          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | -72.7        |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 15           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0061457637 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | -0.000138    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 274          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 401          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 158          |
# |    ep_rew_mean          | -68          |
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 16           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0051663667 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | -1.74e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 152          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 319          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 170        |
# |    ep_rew_mean          | -65.7      |
# | time/                   |            |
# |    fps                  | 421        |
# |    iterations           | 17         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00922423 |
# |    clip_fraction        | 0.0965     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | -7.03e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 237        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00977   |
# |    value_loss           | 353        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | -63.2       |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 18          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005777481 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | 4.54e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 332         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 190        |
# |    ep_rew_mean          | -64.4      |
# | time/                   |            |
# |    fps                  | 416        |
# |    iterations           | 19         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00848032 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | -0.00082   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 129        |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.006     |
# |    value_loss           | 380        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | -62.7       |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 20          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009873245 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | -3.31e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 173         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 392         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | -61.2       |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 21          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007308036 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | -6.09e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | -62.4        |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 22           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0061244415 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | -0.00165     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.1         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 309          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -67.5       |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 23          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010038263 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | -4.05e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 349         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 433         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 246          |
# |    ep_rew_mean          | -72.2        |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 24           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0068133688 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.963       |
# |    explained_variance   | -6.08e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 138          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00537     |
# |    value_loss           | 454          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -69.7       |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 25          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010251256 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -4.15e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 184         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 408         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | -67.8       |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 26          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006529525 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 1.08e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.8        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 291         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | -66.9       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 27          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007352785 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | -6.32e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 149         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 382         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 287        |
# |    ep_rew_mean          | -59.8      |
# | time/                   |            |
# |    fps                  | 390        |
# |    iterations           | 28         |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00998642 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.944     |
# |    explained_variance   | 2.65e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 62.5       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00932   |
# |    value_loss           | 185        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | -56.8       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 29          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008001612 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | -0.000146   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 100         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 353         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 309          |
# |    ep_rew_mean          | -57.6        |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 30           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0074531506 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.88        |
# |    explained_variance   | 3.24e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 121          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 196          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | -63.4        |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 31           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0025294446 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -1e-05       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.4         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 190          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 345          |
# |    ep_rew_mean          | -63.7        |
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 32           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0063372552 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | -7.15e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 145          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 273          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | -60.3       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 33          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008320501 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.000113   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 171         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 372         |
# |    ep_rew_mean          | -60.1       |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 34          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006013762 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | -6.56e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.5        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | -67.6       |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 35          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003990893 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | -1.79e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00397    |
# |    value_loss           | 194         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 36          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009337776 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | -1.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 150         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 238         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 402          |
# |    ep_rew_mean          | -71.9        |
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 37           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0073589543 |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.956       |
# |    explained_variance   | -2.86e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 232          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | -74         |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 38          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008752225 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00921    |
# |    value_loss           | 108         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 426          |
# |    ep_rew_mean          | -73.9        |
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 39           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0033278149 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.6         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000137    |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | -75.4       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 40          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008337132 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.46        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00789    |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 455         |
# |    ep_rew_mean          | -72.5       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 41          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005529497 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | -7.39e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.45        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 25.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 470         |
# |    ep_rew_mean          | -74         |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 42          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007476114 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.99        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00507    |
# |    value_loss           | 17.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 478         |
# |    ep_rew_mean          | -75.7       |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 43          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010482572 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.66        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 21.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 491         |
# |    ep_rew_mean          | -76.7       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 44          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006003962 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.47        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00325    |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 502          |
# |    ep_rew_mean          | -77.1        |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 45           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0067293597 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 19.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 511         |
# |    ep_rew_mean          | -76.5       |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 46          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007387379 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 527         |
# |    ep_rew_mean          | -78.8       |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 47          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005679003 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.79        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 10.4        |
# -----------------------------------------

# %%
env = gym.make("LunarLander-v2", render_mode="human")

# %%
terminated, truncated = False, False
state, _ = env.reset()
while not terminated or truncated:
    action, _ = model.predict(state)
    state, reward, terminated, truncated, info = env.step(action)
